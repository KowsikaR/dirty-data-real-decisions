# %% [markdown]
# # Dirty Data, Real Decisions
# Run the same reproducible pipeline used by `run_analysis.py`.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from run_analysis import main
main()

# %% [markdown]
# The generated reports and figures are written to `reports/` and `outputs/figures/`.
